# %%
import cv2
from paddleocr import PaddleOCR
import pysubs2
from alive_progress import alive_bar

# %% [markdown]
# ## PaddleOCR

# %%
ocr = PaddleOCR(use_angle_cls=True, lang="japan")

# %%
cap = cv2.VideoCapture("小夏4.mp4")
# ret, img = cap.read()
# cv2.imshow("img",img[988:1050,114:1500])
# cv2.waitKey(0)
# cv2.destroyAllWindows()
i=0
while True:
    i+=1
    ret, img = cap.read()
    if ret:
        if i==1205:
            Img = img
            break
    else: 
        break
    # cv2.waitKey(5)
cv2.imshow('img',Img[900:975,100:570])#114,988,1500,1154
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
result = ocr.ocr(Img[988:1154,114:1500])
for line in result:
    text += line[1][0]
print(text)
name = ocr.ocr(Img[900:975,100:570])
# school = ocr.ocr(Img[900:966,105:570])[1][1][0]
print(name)
# Out:
# [2022/01/26 16:19:02] root DEBUG: dt_boxes num : 1, elapse : 0.07878875732421875
# [2022/01/26 16:19:02] root DEBUG: cls num  : 1, elapse : 0.012966156005859375
# [2022/01/26 16:19:02] root DEBUG: rec_res num  : 1, elapse : 0.006981611251831055
# イズミ（美食研究会）：ええつ！？ちょ、ちょっと！待って！私だけ置いていかないで一！？あ
# [2022/01/26 16:19:02] root DEBUG: dt_boxes num : 2, elapse : 0.022938013076782227
# [2022/01/26 16:19:02] root DEBUG: cls num  : 2, elapse : 0.024934768676757812
# [2022/01/26 16:19:02] root DEBUG: rec_res num  : 2, elapse : 0.05784463882446289
# [[[[24.0, 20.0], [105.0, 20.0], [105.0, 53.0], [24.0, 53.0]], ('ナツ', 0.99094546)], [[[126.0, 24.0], [395.0, 28.0], [394.0, 60.0], [125.0, 56.0]], ('放課後スイーツ部', 0.99393046)]]

# %% [markdown]
# ## 时轴样式

# %%
filename = "小夏4"
STYLE_FILE = """\
[Script Info]
; Script generated by Aegisub r8942
; http://www.aegisub.org/
Title: Default Aegisub file
ScriptType: v4.00+
WrapStyle: 0
ScaledBorderAndShadow: yes
YCbCr Matrix: TV.601
PlayResX: 1600
PlayResY: 1200

[Aegisub Project Garbage]
Last Style Storage: 
Audio File: 
Video File: 
Video AR Mode: 4
Video AR Value: 1.333333
Video Zoom Percent: 0.500000
Active Line: 8
Video Position: 1734

[V4+ Styles]
Format: Name, Fontname, Fontsize, PrimaryColour, SecondaryColour, OutlineColour, BackColour, Bold, Italic, Underline, StrikeOut, ScaleX, ScaleY, Spacing, Angle, BorderStyle, Outline, Shadow, Alignment, MarginL, MarginR, MarginV, Encoding
Style: Default,华康圆体W7(P),45,&H00FFFFFF,&H000000FF,&HFF000000,&H00000000,0,0,0,0,100,100,0,0,1,2,0,7,120,10,920,1
Style: 文本,华康圆体W7(P),38,&H00FDFAF8,&H000000FF,&H00000000,&H00000000,-1,0,0,0,100,100,0,0,1,0,0.2,7,120,16,1000,1
Style: 单选,华康圆体W7(P),35,&H00513B30,&HFF0000FF,&HFF6E1C15,&HFF6E0F06,-1,0,0,0,100,100,0,0,1,0,0,8,16,16,510,1
Style: 选项1,华康圆体W7(P),35,&H00513B30,&H000000FF,&H00000000,&H00000000,-1,0,0,0,100,100,0,0,1,0,0,8,16,16,455,1
Style: 选项2,华康圆体W7(P),35,&H00513B30,&H000000FF,&H00000000,&H00000000,-1,0,0,0,100,100,0,0,1,0,0,8,16,16,570,1
Style: 标题,华康圆体W9(P),68,&H00815744,&H000000FF,&HFF000000,&HFF000000,0,0,0,0,100,100,0,0,1,0,0,8,16,16,590,1
Style: 章节,华康圆体W7(P),36,&H00513B30,&H000000FF,&HFF000000,&HFF000000,-1,0,0,0,100,100,0,0,1,0,0,8,16,16,520,1
Style: 羁绊标题,华康圆体W9(P),68,&H00815744,&H000000FF,&HFF000000,&HFF000000,0,0,0,0,100,100,0,0,1,0,0,8,16,16,555,1
Style: 学生,华康圆体W9(P),45,&H00FFFFFF,&H000000FF,&H00000000,&H00000000,0,0,0,0,100,100,0,0,1,1,0,7,120,10,920,1
Style: 文本-fadeout,华康圆体W7(P),38,&H00FDFAF8,&H000000FF,&H00000000,&H00000000,-1,0,0,0,100,100,0,0,1,0,0.2,7,120,16,1000,1
Style: 地点,华康圆体W7(P),33,&H00FDFAF8,&H000000FF,&H00000000,&H00000000,-1,0,0,0,100,100,0,0,1,0,0.2,7,8,16,312,1

[Events]
Format: Layer, Start, End, Style, Name, MarginL, MarginR, MarginV, Effect, Text
"""
with open(filename+".ass", "w", encoding='utf-8') as fp:
    fp.write(STYLE_FILE)

# %%
subs = pysubs2.load(filename+".ass")
subs
# Out:
# <SSAFile with 0 events and 11 styles>

# %%
# 测试
cap = cv2.VideoCapture(filename + ".mp4")
cnt = i = 0
pre_img = np.empty((300,300,3),np.uint8)
pre_flag = cur_flag = False
fps = cap.get(cv2.CAP_PROP_FPS)
while True:
    ret, img = cap.read()
    if ret:#114,988,1500,1154
        result = ocr.ocr(img[988:1050,114:500],rec=False,cls=True)
        cur_flag = (len(result)>0)
        if pre_flag != cur_flag:
            if cnt%2==0:#start
                if i - end < 10:
                    start = end +1
                else:
                    start = i
                print("start : "+str(i))
                cnt+=1
            else :#end
                end = i
                print("end : "+str(i))
                cnt+=1
                result = ocr.ocr(pre_img[988:1154,114:1500])
                text = ""
                for line in result:
                    text += line[1][0]
                if len(text)<=5:
                    text = "TEXT"
                else:
                    name_school = ocr.ocr(pre_img[900:980,90:570])
                    if len(name_school) == 1:
                        print(name_school)
                        text = name_school[0][1][0] + "：" + text
                    if len(name_school) == 2:
                        name = name_school[0][1][0]
                        school = name_school[1][1][0]
                        text = name + "（" + school + "）：" + text
                    else:
                        start -= 4
                print(text)
                subs.insert(0, pysubs2.SSAEvent(start=pysubs2.time.frames_to_ms(start-2, fps), end=pysubs2.time.frames_to_ms(end, fps), text=text,style="文本"))
    else:
        break
    i+=1
    pre_flag = cur_flag
    pre_img = img
cap.release()

subs.save(filename+".ass")
# Out:
# start : 348
# end : 1029
# [2022/01/26 20:49:13] root DEBUG: dt_boxes num : 1, elapse : 0.07079768180847168
# ナツ（放課後スイーツ部）：先手を打たないと。
# start : 1754
# end : 2099
# [2022/01/26 20:49:38] root DEBUG: dt_boxes num : 2, elapse : 0.07079792022705078
# [2022/01/26 20:49:38] root DEBUG: cls num  : 2, elapse : 0.022934436798095703
# [2022/01/26 20:49:38] root DEBUG: rec_res num  : 2, elapse : 0.253277063369751
# [2022/01/26 20:49:38] root DEBUG: dt_boxes num : 2, elapse : 0.0199432373046875
# [2022/01/26 20:49:38] root DEBUG: cls num  : 2, elapse : 0.02393174171447754
# [2022/01/26 20:49:38] root DEBUG: rec_res num  : 2, elapse : 0.05484294891357422
# ナツ（放課後スイーツ部）：というわけでさあさあ、遠慮しなくて良いんだよ～どんっ、牛乳とブルーベリーバ
# start : 2103
# end : 2228
# [2022/01/26 20:49:41] root DEBUG: dt_boxes num : 1, elapse : 0.0717933177947998
# [2022/01/26 20:49:41] root DEBUG: cls num  : 1, elapse : 0.012962818145751953
# [2022/01/26 20:49:41] root DEBUG: rec_res num  : 1, elapse : 0.04786419868469238
# [2022/01/26 20:49:41] root DEBUG: dt_boxes num : 2, elapse : 0.025925636291503906
# [2022/01/26 20:49:41] root DEBUG: cls num  : 2, elapse : 0.02393198013305664
# [2022/01/26 20:49:41] root DEBUG: rec_res num  : 2, elapse : 0.05683755874633789
# ナツ（放課後スイーツ部）：さずがは先生、分かってるね。
# start : 2388
# end : 2390
# [2022/01/26 20:49:45] root DEBUG: dt_boxes num : 0, elapse : 0.07079768180847168
# [2022/01/26 20:49:45] root DEBUG: cls num  : 0, elapse : 0
# [2022/01/26 20:49:45] root DEBUG: rec_res num  : 0, elapse : 0.0
# TEXT
# start : 2391
# end : 2688
# [2022/01/26 20:49:52] root DEBUG: dt_boxes num : 1, elapse : 0.07179474830627441
# [2022/01/26 20:49:52] root DEBUG: cls num  : 1, elapse : 0.011965513229370117
# [2022/01/26 20:49:52] root DEBUG: rec_res num  : 1, elapse : 0.01595473289489746
# TEXT
# start : 2696
# end : 2798
# [2022/01/26 20:49:55] root DEBUG: dt_boxes num : 1, elapse : 0.07279229164123535
# [2022/01/26 20:49:55] root DEBUG: cls num  : 1, elapse : 0.012963294982910156
# [2022/01/26 20:49:55] root DEBUG: rec_res num  : 1, elapse : 0.019942760467529297
# TEXT
# start : 2802
# end : 2956
# [2022/01/26 20:49:59] root DEBUG: dt_boxes num : 1, elapse : 0.07079792022705078
# [2022/01/26 20:49:59] root DEBUG: cls num  : 1, elapse : 0.011965513229370117
# [2022/01/26 20:49:59] root DEBUG: rec_res num  : 1, elapse : 0.10071253776550293
# [2022/01/26 20:49:59] root DEBUG: dt_boxes num : 2, elapse : 0.020940303802490234
# [2022/01/26 20:49:59] root DEBUG: cls num  : 2, elapse : 0.022934436798095703
# [2022/01/26 20:49:59] root DEBUG: rec_res num  : 2, elapse : 0.05484342575073242
# ナツ（放課後スイーツ部）：今回は『何かあった？」みたいなことを聞かれないんだなって。
# start : 2958
# end : 3203
# [2022/01/26 20:50:05] root DEBUG: dt_boxes num : 2, elapse : 0.07279157638549805
# [2022/01/26 20:50:05] root DEBUG: cls num  : 2, elapse : 0.023931503295898438
# [2022/01/26 20:50:05] root DEBUG: rec_res num  : 2, elapse : 0.27521491050720215
# [2022/01/26 20:50:05] root DEBUG: dt_boxes num : 2, elapse : 0.02193737030029297
# [2022/01/26 20:50:05] root DEBUG: cls num  : 2, elapse : 0.02393198013305664
# [2022/01/26 20:50:05] root DEBUG: rec_res num  : 2, elapse : 0.05583930015563965
# ナツ（放課後スイーツ部）：なるほど、本当に先生って表情とかそういう細かいところから丁何かあったのかどうが」が分かるんだな～って思っていやはや、すごいねえ。
# start : 3207
# end : 3375
# [2022/01/26 20:50:09] root DEBUG: dt_boxes num : 1, elapse : 0.06980085372924805
# [2022/01/26 20:50:09] root DEBUG: cls num  : 1, elapse : 0.012963056564331055
# [2022/01/26 20:50:10] root DEBUG: rec_res num  : 1, elapse : 0.11965823173522949
# [2022/01/26 20:50:10] root DEBUG: dt_boxes num : 2, elapse : 0.024929046630859375
# [2022/01/26 20:50:10] root DEBUG: cls num  : 2, elapse : 0.023931026458740234
# [2022/01/26 20:50:10] root DEBUG: rec_res num  : 2, elapse : 0.05484461784362793
# ナツ（放課後スイーツ部）：まあその通り今日は本当に何も無くて、ただ天気が良いなってだけで。
# start : 3379
# end : 3491
# [2022/01/26 20:50:12] root DEBUG: dt_boxes num : 1, elapse : 0.07079744338989258
# [2022/01/26 20:50:12] root DEBUG: cls num  : 1, elapse : 0.011965513229370117
# [2022/01/26 20:50:12] root DEBUG: rec_res num  : 1, elapse : 0.034900665283203125
# [2022/01/26 20:50:12] root DEBUG: dt_boxes num : 2, elapse : 0.019942760467529297
# [2022/01/26 20:50:12] root DEBUG: cls num  : 2, elapse : 0.022933483123779297
# [2022/01/26 20:50:13] root DEBUG: rec_res num  : 2, elapse : 0.054843902587890625
# ナツ（放課後スイーツ部）：でね、ふと思ったの。
# start : 3495
# end : 3777
# [2022/01/26 20:50:19] root DEBUG: dt_boxes num : 3, elapse : 0.07079720497131348
# [2022/01/26 20:50:19] root DEBUG: cls num  : 3, elapse : 0.03390312194824219
# [2022/01/26 20:50:19] root DEBUG: rec_res num  : 3, elapse : 0.40384697914123535
# [2022/01/26 20:50:20] root DEBUG: dt_boxes num : 2, elapse : 0.020940303802490234
# [2022/01/26 20:50:20] root DEBUG: cls num  : 2, elapse : 0.0229337215423584
# [2022/01/26 20:50:20] root DEBUG: rec_res num  : 2, elapse : 0.05484318733215332
# ナツ（放課後スイーツ部）：いつも生徒たちの相談とかで忙しい先生に対して、本当に何も無い時に突然連絡したつ…その時、先生は何かあったと思うのかな？どうしたの？！って聞いてくるのがなて
# start : 3779
# end : 3897
# [2022/01/26 20:50:22] root DEBUG: dt_boxes num : 1, elapse : 0.06980061531066895
# [2022/01/26 20:50:22] root DEBUG: cls num  : 1, elapse : 0.012962818145751953
# [2022/01/26 20:50:59] root DEBUG: dt_boxes num : 2, elapse : 0.020940065383911133
# [2022/01/26 20:50:59] root DEBUG: cls num  : 2, elapse : 0.022934436798095703
# [2022/01/26 20:50:59] root DEBUG: rec_res num  : 2, elapse : 0.05484342575073242
# ナツ（放課後スイーツ部）：呼び出しておいてなんだけど、その忙しいところ迷惑かけちゃってたら
# start : 5383
# end : 5656
# [2022/01/26 20:51:05] root DEBUG: dt_boxes num : 1, elapse : 0.07279276847839355
# [2022/01/26 20:51:05] root DEBUG: cls num  : 1, elapse : 0.011965036392211914
# [2022/01/26 20:51:05] root DEBUG: rec_res num  : 1, elapse : 0.03888964653015137
# [2022/01/26 20:51:05] root DEBUG: dt_boxes num : 2, elapse : 0.02093982696533203
# [2022/01/26 20:51:05] root DEBUG: cls num  : 2, elapse : 0.023932456970214844
# [2022/01/26 20:51:05] root DEBUG: rec_res num  : 2, elapse : 0.05284881591796875
# ナツ（放課後スイーツ部）：それは悲しいな一って。
# start : 5660
# end : 5804
# [2022/01/26 20:51:09] root DEBUG: dt_boxes num : 1, elapse : 0.07379031181335449
# [2022/01/26 20:51:09] root DEBUG: cls num  : 1, elapse : 0.01296234130859375
# [2022/01/26 20:51:09] root DEBUG: rec_res num  : 1, elapse : 0.08176565170288086
# [2022/01/26 20:51:09] root DEBUG: dt_boxes num : 2, elapse : 0.023932218551635742
# [2022/01/26 20:51:09] root DEBUG: cls num  : 2, elapse : 0.02393198013305664
# [2022/01/26 20:51:09] root DEBUG: rec_res num  : 2, elapse : 0.05583977699279785
# ナツ（放課後スイーツ部）：あははっ、そこまで言ってくれると嬉しいなあ。
# start : 5808
# end : 6044
# [2022/01/26 20:51:15] root DEBUG: dt_boxes num : 2, elapse : 0.07378864288330078
# [2022/01/26 20:51:15] root DEBUG: cls num  : 2, elapse : 0.023931503295898438
# [2022/01/26 20:51:15] root DEBUG: rec_res num  : 2, elapse : 0.2732200622558594
# [2022/01/26 20:51:15] root DEBUG: dt_boxes num : 2, elapse : 0.021937131881713867
# [2022/01/26 20:51:15] root DEBUG: cls num  : 2, elapse : 0.02393174171447754
# [2022/01/26 20:51:15] root DEBUG: rec_res num  : 2, elapse : 0.05484461784362793
# ナツ（放課後スイーツ部）：こうやって何の理由ちなく呼び出して一緒に時間を過ごしてくれる相手もゃまあ何人かはいてくれるんだけど、なかなか貴重だからね。
# start : 6302
# end : 6456
# [2022/01/26 20:51:24] root DEBUG: dt_boxes num : 1, elapse : 0.07079768180847168
# [2022/01/26 20:51:24] root DEBUG: cls num  : 1, elapse : 0.011965513229370117
# [2022/01/26 20:51:24] root DEBUG: rec_res num  : 1, elapse : 0.10170936584472656
# [2022/01/26 20:51:25] root DEBUG: dt_boxes num : 2, elapse : 0.020940303802490234
# [2022/01/26 20:51:25] root DEBUG: cls num  : 2, elapse : 0.022934436798095703
# [2022/01/26 20:51:25] root DEBUG: rec_res num  : 2, elapse : 0.05384707450866699
# ナツ（放課後スイーツ部）：`うん、こういう話はもう終わり！真面目な話は今したくない！
# [2022/01/26 20:51:52] root DEBUG: rec_res num  : 1, elapse : 0.08176684379577637
# [2022/01/26 20:51:52] root DEBUG: dt_boxes num : 0, elapse : 0.018946409225463867
# [2022/01/26 20:51:52] root DEBUG: cls num  : 0, elapse : 0
# [2022/01/26 20:51:52] root DEBUG: rec_res num  : 0, elapse : 0.0
# (ナツはそう言って嬉しそうに、パイを口に運んだ
# start : 7656
# end : 7810
# [2022/01/26 20:51:56] root DEBUG: dt_boxes num : 1, elapse : 0.06980037689208984
# [2022/01/26 20:51:56] root DEBUG: cls num  : 1, elapse : 0.012963056564331055
# [2022/01/26 20:51:56] root DEBUG: rec_res num  : 1, elapse : 0.08475852012634277
# [2022/01/26 20:51:56] root DEBUG: dt_boxes num : 0, elapse : 0.018945932388305664
# [2022/01/26 20:51:56] root DEBUG: cls num  : 0, elapse : 0
# [2022/01/26 20:51:56] root DEBUG: rec_res num  : 0, elapse : 0.0
# (その後ナツと一緒に色々と楽しんだ後、シャーレへと戻った

# %% [markdown]
# # cv 读入

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
video_filename = '补习部2章6.mp4'
videoCap = cv2.VideoCapture(video_filename)

# 帧频
fps = videoCap.get(cv2.CAP_PROP_FPS)
# 视频总帧数
total_frames = int(videoCap.get(cv2.CAP_PROP_FRAME_COUNT))
# 图像尺寸
image_size = (int(videoCap.get(cv2.CAP_PROP_FRAME_HEIGHT)), int(videoCap.get(cv2.CAP_PROP_FRAME_WIDTH)))

print(fps)
print(total_frames)
print(image_size)

# %%
sucess, frame = videoCap.read()

# 跳过开头
for i in range(718):
    sucess, frame = videoCap.read()
plt.imshow(frame)

plt.imshow(frame[908:970,114:270])
im = frame[988:1050,114:500]

# %% [markdown]
# ## 像素点的平方误差之和的平均值

# %%
thresh = 220
_, im = cv2.threshold(im, thresh, 255, cv2.THRESH_BINARY)
plt.imshow(im)
print(im.shape)

# %%
def cal_stderr(img):
    if img is None:
        return 0
    return (img ** 2).sum() / img.size * 100

# %%
# 测试
videoCap = cv2.VideoCapture(video_filename)
curr_frame = 0
fps = videoCap.get(cv2.CAP_PROP_FPS)
success = True
subtitle_img = None
last_img = None
img_count = 0
start = end = 0

flag = True
while True:
    success, frame = videoCap.read()
    curr_frame += 1
    if frame is None:
        print('video: %s finish at %d frame.' % (video_filename, curr_frame))
        break
    im = frame[:, :, 0]
    img = im[988:1050,114:500]
    _, img = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY)

    img0 = im[908:970,114:270]
    _, img0 = cv2.threshold(img0, 220, 255, cv2.THRESH_BINARY)
    if cal_stderr(img0) >= 0.1 and flag == True:
        start0 = curr_frame
        flag = False
    if cal_stderr(last_img) < 0.1 and cal_stderr(img) >=0.1 :
        start = curr_frame-3
        if start - end < 5:
            start = end+1
        else:
            start = start0-1
        print("start "+str(start))
    elif cal_stderr(last_img) >= 0.1 and cal_stderr(img) <0.1:
        end = curr_frame-2
        print("end "+str(end))
        flag = True
    last_img = img
